# %% [markdown]
# 1 to 5: Maximum yields
#
# 6 to 10: Heterologous reaction that improves maximum theoretical yield
#
# 11 to 13: Cofactor swapping target reactions
#
# 14 to 18: FVSEOF simulations
#
# 19 to 23: iBridge simulation

# %%
import pandas as pd 
filename = '1.csv'
df = pd.read_csv(filename)
df
# Out:
#      Template model             Target model Target chemical  Target ID  \
# 0            iYO844           iYO844_actn__R     (R)-acetoin    actn__R
# 1            iYO844           iYO844_actn__R     (R)-acetoin    actn__R
# 2            iYO844           iYO844_actn__R     (R)-acetoin    actn__R
# 3            iYO844           iYO844_actn__R     (R)-acetoin    actn__R
# 4            iYO844           iYO844_actn__R     (R)-acetoin    actn__R
# ...             ...                      ...             ...        ...
# 5435    iYO844_rump              iYO844_caro   beta-carotene       caro
# 5436    iYO844_rump         iYO844_met_28398     butan-2-one  met_28398
# 5437    iYO844_rump         iYO844_met_28398     butan-2-one  met_28398
# 5438    iYO844_rump  iYO844_met_28398_path_1     butan-2-one  met_28398
# 5439    iYO844_rump  iYO844_met_28398_path_1     butan-2-one  met_28398
#
#      Yield type Oxygen availability Carbon source  molar yield (mol/mol)  \
# ...
